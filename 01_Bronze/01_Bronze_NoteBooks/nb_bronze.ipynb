# %%
customers_df = spark.read.table("global_warehouse.azure_blob_storage.customers")
display(customers_df)

# %%
customers_df = customers_df.drop("_file","_line","_modified","_fivetran_synced")

# %%
exchange_rates_df = spark.read.table("global_warehouse.azure_blob_storage.exchange_rates")
display(exchange_rates_df)

# %%
exchange_rates_df = exchange_rates_df.drop("_file","_line","_modified","_fivetran_synced")
display(exchange_rates_df)

# %%
invoice_line_items_df = spark.read.table("global_warehouse.azure_blob_storage.invoice_line_items")
invoices_df = spark.read.table("global_warehouse.azure_blob_storage.invoices")
payments_df = spark.read.table("global_warehouse.azure_blob_storage.payments")
products_df = spark.read.table("global_warehouse.azure_blob_storage.products")
regions_df = spark.read.table("global_warehouse.azure_blob_storage.regions")

# %%
invoice_line_items_df = invoice_line_items_df.drop("_file","_line","_modified","_fivetran_synced")
invoices_df = invoices_df.drop("_file","_line","_modified","_fivetran_synced")
payments_df = payments_df.drop("_file","_line","_modified","_fivetran_synced")
products_df = products_df.drop("_file","_line","_modified","_fivetran_synced")
regions_df = regions_df.drop("_file","_line","_modified","_fivetran_synced")

# %%
display(invoice_line_items_df) 
display(invoices_df)
display(payments_df)
display(products_df)
display(regions_df)

# %%
catalog_name = "br_global_warehouse"
schema_name = "br_warehouse_schema"
table_name = "br_customers"
table_path = f"{catalog_name}.{schema_name}.{table_name}"

customers_df.write.mode("overwrite").saveAsTable(table_path)

# %%
catalog_name = "br_global_warehouse"
schema_name = "br_warehouse_schema"
table_name = "br_exchange_rates"
table_path = f"{catalog_name}.{schema_name}.{table_name}"

exchange_rates_df.write.mode("overwrite").saveAsTable(table_path)

# %%
catalog_name = "br_global_warehouse"
schema_name = "br_warehouse_schema"
table_name = "br_invoice_line_items"
table_path = f"{catalog_name}.{schema_name}.{table_name}"

invoice_line_items_df.write.mode("overwrite").saveAsTable(table_path)

# %%
catalog_name = "br_global_warehouse"
schema_name = "br_warehouse_schema"
table_name = "br_invoices"
table_path = f"{catalog_name}.{schema_name}.{table_name}"

invoices_df.write.mode("overwrite").saveAsTable(table_path)

# %%
catalog_name = "br_global_warehouse"
schema_name = "br_warehouse_schema"
table_name = "br_payments"
table_path = f"{catalog_name}.{schema_name}.{table_name}"

payments_df.write.mode("overwrite").saveAsTable(table_path)

# %%
catalog_name = "br_global_warehouse"
schema_name = "br_warehouse_schema"
table_name = "br_products"
table_path = f"{catalog_name}.{schema_name}.{table_name}"

products_df.write.mode("overwrite").saveAsTable(table_path)

# %%
catalog_name = "br_global_warehouse"
schema_name = "br_warehouse_schema"
table_name = "br_regions"
table_path = f"{catalog_name}.{schema_name}.{table_name}"

regions_df.write.mode("overwrite").saveAsTable(table_path)
